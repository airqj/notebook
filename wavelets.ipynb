# %%
import pywt

# %%
import librosa
import matplotlib.pyplot as plt

# %%
ainai = librosa.load("/home/qinjianbo/Desktop/ainai_8000.mp3",mono=True)

# %%
print(ainai)
# %matplotlib inline
# Out:
# (array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#        -3.0844039e-05, -2.5702688e-05,  0.0000000e+00], dtype=float32), 22050)

# %%
cA,cD = pywt.cwt(ainai[0][:1000],np.arange(1,129),"gaus1")

# %%
plt.show()

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-1, 1, 200, endpoint=False)
sig  = np.cos(2 * np.pi * 7 * t) + np.real(np.exp(-7*(t-0.4)**2)*np.exp(1j*2*np.pi*2*(t-0.4)))
widths = np.arange(1, 31)
cwtmatr, freqs = pywt.cwt(sig, widths, 'mexh')
plt.imshow(cwtmatr, extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())  
plt.show()

# %%
x = np.arange(512)
y = np.sin(2*np.pi*x/32)
coef, freqs=pywt.cwt(y,np.arange(1,129),'gaus1')
plt.matshow(coef) 
plt.show()

# %%
np.shape(coef)
# Out:
# (128, 512)

# %%
np.shape(freqs)
# Out:
# (128,)

# %%
coef[0]
# Out:
# array([-0.0675241 , -0.23907145, -0.2916507 , -0.27168006, -0.23814829,
#        -0.19544327, -0.14522745, -0.08943062, -0.03019703,  0.03019703,
#         0.08943062,  0.14522745,  0.19544327,  0.23814831,  0.27170145,
#         0.29481326,  0.30659555,  0.30659555,  0.29481326,  0.27170145,
#         0.23814831,  0.19544327,  0.14522745,  0.08943062,  0.03019703,
#        -0.03019703, -0.08943062, -0.14522745, -0.19544327, -0.23814831,
#        -0.27170145, -0.29481326, -0.30659555, -0.30659555, -0.29481326,
#        -0.27170145, -0.23814831, -0.19544327, -0.14522745, -0.08943062,
#        -0.03019703,  0.03019703,  0.08943062,  0.14522745,  0.19544327,
#         0.23814831,  0.27170145,  0.29481326,  0.30659555,  0.30659555,
#         0.29481326,  0.27170145,  0.23814831,  0.19544327,  0.14522745,
#         0.08943062,  0.03019703, -0.03019703, -0.08943062, -0.14522745,
#        -0.19544327, -0.23814831, -0.27170145, -0.29481326, -0.30659555,
# ...
