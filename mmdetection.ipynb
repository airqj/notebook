# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = '/home/qinjianbo/SRC/mmdetection/configs/cascade_rcnn_r101_fpn_1x_spec.py'
checkpoint_file = '/home/qinjianbo/SRC/mmdetection/work_dirs/cascade_rcnn_r101_fpn_1x/epoch_30.pth'

# %%
model = init_detector(config_file, checkpoint_file, device='cuda:0')

# %%
img = '/tmp/specs/1564761539_1_0.png'

# %%
result = inference_detector(model,img)

# %%
show_result_pyplot(img,result,model.CLASSES)

# %%
result[0].shape
# Out:
# (18, 5)
