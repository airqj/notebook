# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(open("/home/qinjianbo/Downloads/律和古琴工作室.html"),"lxml")

# %%
entrys = data.find_all(class_ = "weui_media_title")

# %%
entry = entrys[0]

# %%
entry.text.replace("\n","").strip()
# Out:
# '新品发售 | 《张子谦操缦艺术》专辑增订版首发，纪念古琴大家张子谦先生诞辰120周年'

# %%
a="12344"

# %%
for entry in entrys:
    title = entry.text.replace("\n","").strip()
    href  = entry['hrefs'].split("&chksm")[0]
    print(title,href,"\n")
# Out:
# 新品发售 | 《张子谦操缦艺术》专辑增订版首发，纪念古琴大家张子谦先生诞辰120周年 http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365076&idx=1&sn=c87b7d98707c0be23468b129a3aef057
#
# 古琴课程信息：《庄周梦蝶》单曲班 | 陈长林先生亲自指导 陈燕主讲 http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365072&idx=1&sn=e2f088f9b710f293b2c7097bca2c7cd7
#
# 古琴知识百问连载（十二）----古琴要养么？会越弹越好么？（上） http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365068&idx=1&sn=c64ab36b63b57206eb8d4cdd457925e9
#
# 琴友福利--“王宁古琴工作室”网店双十一红包安排 http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365064&idx=1&sn=462cf7638cd2ff101b465e86d1eb57c2
#
# 启功：我的毛笔，7分钱一支…… http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365057&idx=1&sn=f6d3f8cb19f04133235509d2751d26ab
#
# 乐圣新品“云和”“润和”正式公开发售 http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365051&idx=1&sn=c91a6d248d007a831c3f9c039f9c2446
#
# 律和小课堂——刘泽鑫《古代白话文献选读》第二课视频公开 http://mp.weixin.qq.com/s?__biz=MzA4OTM5NDM2OA==&mid=2660365046&idx=1&sn=b2d64ae7db1f00f69c181d544221220c
#
# ...
