# %%
import numpy as np
import os,cv2
import pickle
from PIL import Image
from matplotlib import pyplot
from dtw import dtw

# %%
jianzipu_dir = "/home/qinjianbo/DATA/jianzipu_resize/"

# %%
def read_img(path):
    data_img = cv2.imread(file_path)[0]
    return data_img

# %%
data_map = {}
for file in os.listdir(jianzipu_dir):
    file_path = jianzipu_dir + file
    data = read_img(file_path)
    data_map[file] = data

# %%
image = cv2.imread("/home/qinjianbo/DATA/jianzipu/" + "mmexport1573788772697.png")

# %%
data_map
# Out:
# {'mmexport1573787775659.png': array([[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]], dtype=uint8),
#  'mmexport1573788404747.png': array([[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# !ls
# Out:
# jianzipu.ipynb

# %%
cv2.imwrite("/home/qinjianbo/Desktop/aa.jpeg",image[:,:,1])
# Out:
# True

# %%
file_write = open("/home/qinjianbo/DATA/jianzipu_data","wb")
pickle.dump(data_map,file_write)
file_write.close()

# %%
pickle.dump(data_map,file)

# %%
file.close()

# %%
euclidean_norm = lambda x, y: np.abs(x - y)

# %%
file_read = open("/home/qinjianbo/DATA/jianzipu_data","rb")
data_jianzipu = pickle.load(file_read)

# %%
distance_map = {}
data_input = read_img("/home/qinjianbo/Downloads/261811281.png")

# %%
for k,v in data_jianzipu.items():
    d,_,_,_ = dtw(data_input,v,dist=euclidean_norm)
    distance_map[k] = d

# %%
data_input
# Out:
# array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)

# %%
d,_,_,_ = dtw()
